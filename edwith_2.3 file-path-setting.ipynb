# %%
# %mv ~/downloads + tabs키
# 파일명 . >> 파일을 여기 경로로 옮긴다

# %%
# %mv C:/Users/sarah/Downloads/도로교통공단_교통사고다발지역_20191010.csv .
# Out:
# UsageError: Line magic function `%mv` not found.

# %%
# jupyter notebook이 있는 폴더의 경로를 출력
# %pwd
# Out:
# 'C:\\Users\\sarah\\Documents\\jupyternotebook-tutorials'

# %%
# %ls
# Out:
#  C 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: C6D2-291F
#
#  C:\Users\sarah\Documents\jupyternotebook-tutorials 디렉터리
#
# 2020-03-10  오후 03:35    <DIR>          .
# 2020-03-10  오후 03:35    <DIR>          ..
# 2020-03-10  오후 03:34    <DIR>          .ipynb_checkpoints
# 2020-03-10  오후 03:35    <DIR>          data
# 2020-03-09  오후 09:51            58,886 edwith_2.2 pandas cheatsheet.ipynb
# 2020-03-09  오후 07:55            13,899 edwith_python.ipynb
# 2020-03-10  오후 03:32            17,316 file-path-setting.ipynb
# 2020-03-05  오후 03:47            22,664 my 1st Jupyter Notebook.ipynb
# 2020-03-06  오후 10:59             4,680 Pandas tutorial.ipynb
# 2020-03-09  오후 09:52           345,905 Pandas_Cheat_Sheet.pdf
#                6개 파일             463,350 바이트
#                4개 디렉터리  143,344,930,816 바이트 남음

# %%
import pandas as pd

# %%
# shift+tab 도움말
# cp949 : 한글폰트를 깨짐없이 인코딩
pd.read_csv("data/도로교통공단_교통사고다발지역_20191010.csv", encoding="cp949")
# Out:
#        사고지역관리번호  사고년도  사고유형구분       위치코드      시도시군구명  \
# 0       2013060  2012  스쿨존어린이   11110001  서울특별시 종로구1
# 1       2013060  2012  스쿨존어린이   11290001  서울특별시 성북구1
# 2       2013060  2012  스쿨존어린이   11290002  서울특별시 성북구2
# 3       2013060  2012  스쿨존어린이   11290003  서울특별시 성북구3
# 4       2013060  2012  스쿨존어린이   11320001  서울특별시 도봉구1
# ...         ...   ...     ...        ...         ...
# 10360   2019066  2018    무단횡단  280641002      경기 파주2
# 10361   2019066  2018    무단횡단  280641003      경기 파주3
# 10362   2019066  2018    무단횡단  280641004      경기 파주4
# 10363   2019066  2018    무단횡단  280941001      경기 구리1
# 10364   2019066  2018    무단횡단  281041001      경기 포천1
#
#                            사고지역위치명  발생건수  사상자수  사망자수  중상자수  경상자수  부상자수  \
# 0           서울특별시 종로구 혜화동(혜화초교 부근)     2     2     0     1     1     0
# 1           서울특별시 성북구 종암동(숭례초교 부근)     2     2     0     0     1     1
# 2        서울특별시 성북구 동소문동7가(정덕초교 부근)     2     2     0     2     0     0
# ...
